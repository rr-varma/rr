# %% [markdown]
# <a href="https://colab.research.google.com/github/rr-varma/rr/blob/main/diabetesclassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Diabetes.csv')

# %%
diabetes.describe()
# Out:
#        pregnancies     glucose   diastolic     triceps     insulin  \
# count   768.000000  768.000000  768.000000  768.000000  768.000000
# mean      3.845052  120.894531   69.105469   20.536458   79.799479
# std       3.369578   31.972618   19.355807   15.952218  115.244002
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       1.000000   99.000000   62.000000    0.000000    0.000000
# 50%       3.000000  117.000000   72.000000   23.000000   30.500000
# 75%       6.000000  140.250000   80.000000   32.000000  127.250000
# max      17.000000  199.000000  122.000000   99.000000  846.000000
#
#               bmi         dpf         age    diabetes
# count  768.000000  768.000000  768.000000  768.000000
# mean    31.992578    0.471876   33.240885    0.348958
# std      7.884160    0.331329   11.760232    0.476951
# min      0.000000    0.078000   21.000000    0.000000
# 25%     27.300000    0.243750   24.000000    0.000000
# ...

# %%
diabetes.head()
# Out:
#    pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0            6      148         72       35        0  33.6  0.627   50
# 1            1       85         66       29        0  26.6  0.351   31
# 2            8      183         64        0        0  23.3  0.672   32
# 3            1       89         66       23       94  28.1  0.167   21
# 4            0      137         40       35      168  43.1  2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
diabetes.columns
# Out:
# Index(['pregnancies', 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi',
#        'dpf', 'age', 'diabetes'],
#       dtype='object')

# %%
#target value
y = diabetes['diabetes']

# %%
# define features (X)
X = diabetes.drop(['diabetes'], axis=1)

# %%
X = diabetes[['pregnancies', 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi',
       'dpf', 'age']]

# %%
# import train test split function
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7,stratify=y,random_state=2529)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((537, 8), (231, 8), (537,), (231,))

# %%
X_train
# Out:
#      pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age
# 377            1       87         60       37       75  37.2  0.509   22
# 393            4      116         72       12       87  22.1  0.463   37
# 662            8      167        106       46      231  37.6  0.165   43
# 367            0      101         64       17        0  21.0  0.252   21
# 233            4      122         68        0        0  35.0  0.394   29
# ..           ...      ...        ...      ...      ...   ...    ...  ...
# 689            1      144         82       46      180  46.1  0.335   46
# 730            3      130         78       23       79  28.4  0.323   34
# 464           10      115         98        0        0  24.0  1.022   34
# 223            7      142         60       33      190  28.8  0.687   61
# 485            0      135         68       42      250  42.3  0.365   24
#
# [537 rows x 8 columns]

# %%
#step 5
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=300)  #by default iteration time is 100 but we can change by LogisticRegression(max_iter=500)

# %%
#step 6 train model or fit
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=300)

# %%
#step 7
y_pred = model.predict(X_test)

# %%
# step 8
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.7619047619047619

# %%
# Step 8 : model accuracy
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[130,  20],
#        [ 35,  46]])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7619047619047619

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83       150
#            1       0.70      0.57      0.63        81
#
#     accuracy                           0.76       231
#    macro avg       0.74      0.72      0.73       231
# weighted avg       0.76      0.76      0.76       231
